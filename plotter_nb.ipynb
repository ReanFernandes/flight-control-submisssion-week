# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <h1> DMS</h1>

# %% [markdown]
# Number of horizons vs computation time

# %%
#Create a line chart with the number of horizons on the x-axis and computation time on the y-axis the step in x-axis is 5
horizon = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
time = [26.367902755737305,57.85393714904785, 112.89310455322266,112.0483875274658,139.2672061920166,195.01996040344238,223.20294380187988,268.8415050506592,307.18994140625,352.0064353942871 ]
plt.plot(horizon, time, 'r-o')
#x-axis increments in steps of 5
plt.xticks([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])
plt.grid()
plt.xlabel('Horizon length N')
plt.ylabel('Computation time (ms)')
plt.legend(['Computation time'])
plt.title('Computation time vs Horizon for Direct Multiple Shooting')

plt.savefig('DMS_N_vs_comp_time.png')

# %%
import numpy as np
N5=[0.7035623639735145, 0.6971266157103846, 0.6777332276584702, 0.6452814981832093, 0.5997436955999738, 0.5483641940168053]
N10=[0.7035623639735143, 0.6971277449481507, 0.6777362613253274, 0.6452854522069451, 0.5997470423606555, 0.5410955772756465, 0.46930664931015004, 0.38435600801365455, 0.29617144767683473, 0.2191241390076107, 0.15343744082461305]
N15=[0.7035623639735143, 0.6973034755744597, 0.6782241050430468, 0.6460739590081919, 0.6013101545687259, 0.5442072882280217, 0.47439587529477356, 0.3928428791006806, 0.3015532211036166, 0.21325349780611785, 0.14024254593476154, 0.0829545506177225, 0.04142491062868223, 0.01572585145490968, 0.005278435124578359, 0.001963156501017201]
N20=[0.7035623639735143, 0.6987400623814474, 0.6846661174224302, 0.6620833629756817, 0.6317025924774315, 0.5942954467301663, 0.5507370136938664, 0.5020276796656984, 0.4493010272699786, 0.39381689992402513, 0.33693935739100916, 0.2801030469945366, 0.2247768842131246, 0.17243637357856337, 0.12454952016703898, 0.08256620045551694, 0.04789119808576658, 0.021834529044740186, 0.005558449284395637, 5.159766427141958e-09, 1.3041800707783164e-09]
N25=[0.7035623639735143, 0.6990559511568182, 0.6862218863110535, 0.6662731409810027, 0.6402183277467777, 0.6089990637244788, 0.5735209562627294, 0.5346602723416436, 0.49326183693785075, 0.4501333815614658, 0.4060390642920817, 0.3616938350258591, 0.3177595981105708, 0.27484355194840476, 0.23349869484738198, 0.19422630946134883, 0.1574802493284474, 0.12367298469427307, 0.09318354540678796, 0.066367654441731, 0.04357040159606153, 0.025141669408087815, 0.011454074514884852, 0.002922141513411668, 1.9645834703997547e-09, 4.0697667607398313e-10]
N30=[0.7035623639735143, 0.6991311796883857, 0.6866118701215629, 0.6673743075870799, 0.6425487593374363, 0.613166214465522, 0.5801842935928195, 0.5444892424254737, 0.5068916926208015, 0.4681224028889369, 0.4288304859534935, 0.3895847502018733, 0.3508777375917503, 0.3131315754468219, 0.2767047026165497, 0.24189869562285501, 0.20896466153577992, 0.17810889181425804, 0.1494976497667065, 0.12326109207305536, 0.09949641646798284, 0.07827040312837036, 0.05962159748633011, 0.043562486807136744, 0.03008216293199344, 0.0191501201727619, 0.010721944969002818, 0.004747699099465653, 0.001183979251498857, 2.392332415187285e-09, 3.564107297941137e-10]
N50=[0.7035623639735143, 0.6991349544153005, 0.6866418185061124, 0.6674811370137177, 0.6428067937859337, 0.6136692810002339, 0.5810458324567901, 0.5458449181903241, 0.5089033729625623, 0.47098298734653116, 0.4327696526984839, 0.3948761686709682, 0.3578486256991844, 0.3221756494714121, 0.28829953064728353, 0.25662804695684854, 0.22754520845155232, 0.20141773953899497, 0.17859148550240592, 0.1593686743473631, 0.14395658002965434, 0.1323884533515076, 0.12444393185851049, 0.1196217534621456, 0.11720287249482736, 0.11638146246601477, 0.11639663976833613, 0.1166143049435942, 0.1165532535324826, 0.1158757202013388, 0.11436359170553982, 0.1118930226046414, 0.10841270946880817, 0.10392698180911229, 0.09848321539206924, 0.09216263402571512, 0.08507360175738463, 0.07734667541386946, 0.069130856473507, 0.060590512756250055, 0.05190307223102832, 0.04325672283599941, 0.03484792965379179, 0.026879264539056424, 0.019557176936744993, 0.013090072613596697, 0.0076871938332084685, 0.00355903256881973, 0.0009201725404118993, 5.3852036996322904e-09, 4.640951413675585e-10]
# make all the variables the same lenght as N50, by repeating the last variable of each list
N5 = N5 + [N5[-1]]*(len(N50)-len(N5))
N10 = N10 + [N10[-1]]*(len(N50)-len(N10))
N15 = N15 + [N15[-1]]*(len(N50)-len(N15))
N20 = N20 + [N20[-1]]*(len(N50)-len(N20))
N25 = N25 + [N25[-1]]*(len(N50)-len(N25))
N30 = N30 + [N30[-1]]*(len(N50)-len(N30))
N35 = N35 + [N35[-1]]*(len(N50)-len(N35))
N40 = N40 + [N40[-1]]*(len(N50)-len(N40))
N45 = N45 + [N45[-1]]*(len(N50)-len(N45))

#plot all the list vs an x_axis of 0 to 50 

x_axis = np.arange(0,51,1)

plt.plot(x_axis, N10, label = "N=10")
plt.plot(x_axis, N15, label = "N=15")
plt.plot(x_axis, N20, label = "N=20")
plt.plot(x_axis, N25, label = "N=25")
plt.plot(x_axis, N30, label = "N=30")
plt.plot(x_axis, N35, label = "N=35")
plt.plot(x_axis, N40, label = "N=40")
plt.plot(x_axis, N45, label = "N=45")
plt.plot(x_axis, N50, label = "N=50")

plt.xlabel(" Step")
plt.ylabel(" Deviation from reference")
plt.title("Progress towards reference for different horizon lengths for DMS")
plt.legend()
plt.savefig("DMS_N_vs_deviation.png")

# %%
solution_time = [87.4693393707,173.7418174743,184.4990253448,253.37791442871,247.682332992,248.311042785644,691.0612583,620.355606079]
step_length = [0.001, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1.0]
final_deviation = [0.7031129805140249, 0.1706711141327864,0.016064290341788634,0.0003573790103615452,1.9678320120184308e-05,1.2703158693457595e-06,2.7638535047663382e-08,1.4033745166466095e-09
]
#  Create a 3D scatter plot with steplength on the x-axis, final deviation from reference on the y-axis, and solution time on the z-axis. 
# the x_axis points are the step_length
#  Make the size of the dots proportional to the solution time.
# Make the color of the dots proportional to the solution time.
#  Add a colorbar to the plot.
#  Add a title to the plot.
#  Add labels to the axes.
# %matplotlib widget

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(step_length, final_deviation, solution_time, s=solution_time, c=solution_time)
ax.set_xlabel("Step length")
ax.set_ylabel("Final deviation from reference")
ax.set_zlabel("Solution time")
ax.set_title("Solution time for different step lengths")
fig.colorbar(ax.scatter(step_length, final_deviation, solution_time, s=solution_time, c=solution_time))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

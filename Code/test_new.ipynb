# %% [markdown]
# DMS

# %%
from NMPC_solver import *
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x_start = [ 0, 0.0, 0.0]
x_desired = [0.3, 0.4, 0.4]

# %%
Q = np.diag([120,
            100,
            100,
            1,
            1,
            1,
            1,
            7e-1,
            1.0,
            4.0,
            1e-2,
            1e-2,
            1e-2])
R = np.diag([1, 1, 1, 1])*0.1

solver_bounds = {"upper_pose_limit":[1, 1, 1.5],
                "lower_pose_limit":[-1, -1, 0],
                "upper_vel_limit":[2.5, 2.5, 2.5],
                "lower_vel_limit":[-2.5, -2.5, -2.5],
                "upper_att_limit": [inf]*4,#[1,1,1,1],
                "lower_att_limit":[-inf]*4,#[0,-1,-1,-1],
                "upper_ang_limit":[10, 10, 10],
                "lower_ang_limit":[-10, -10, -10],
                "u_min" : [ 0, 0, 0, 0],
                "u_max" : [ 22, 22, 22, 22]}

nlp_opts = {"ipopt": {"max_iter": 3000, "print_level" :0}, "jit": False, "print_time":0}
# nlp_opts = {"max_iter":1}
# nlp_opts = {"qpsol_options": {"max_iter":20}}
cost_type = "slack"      # use slack variables for the terminal cost          
# time for dms closed loop
dms_timing = { "frequency" : 50,         # sampling frequency
            # "solution_time" : 0.05,      # real world time to navigate the drone
            "N" : 5    ,   
            "DMS_RK4_step_size" : 2, # step size of RK4 method for DMS
            "degree" : 2}           # degree of the collocation polynomial  
# time for dc closed loop
dc_timing = { "frequency" : 50,         # sampling frequency
            "solution_time" : 0.1, 
            "N" : 5   , # real world time to navigate the drone
            "DMS_RK4_step_size" : 2, # step size of RK4 method for DMS
            "degree" : 3}       

min_deviation = 0.05

# %%
# %autoreload
dms_open_loop = solver(dms_timing, solver_bounds, nlp_opts, Q, R )  # open loop by default
dc_open_loop = solver(dc_timing, solver_bounds, nlp_opts, Q, R, cost_type = False)

# %%
dms_open_loop.set_initial_values(x_start, x_desired)
dms_open_loop.create_dms_solver()
dms_open_loop.solve()
dms_open_loop._extract_solution()
print(dms_open_loop.deviation_list)
# Out:
# IPOPT status: Solve_Succeeded
# [0.6403124237432849, 0.6399637821029662, 0.6389196432244599, 0.6376326537900954, 0.6367414994942201, 0.6364420841597946]

# %%
dc_open_loop.set_initial_values(x_start, x_desired)
# dc_open_loop.initial_state_guess = np.zeros((13,))
dc_open_loop.create_dc_solver()
dc_open_loop.solve()
dc_open_loop._extract_solution()
# Out:
# IPOPT status: Solve_Succeeded

# %%
dc_open_loop.solver_time
# Out:
# 0.024641752243041992

# %%
#repeat the last element in dc_open_loop.deviation_list so that deviation_list_dc has lentght 50
deviation_list_dc = np.concatenate((np.array(dc_open_loop.deviation_list), np.array([dc_open_loop.deviation_list[-1]]*(50 - len(dc_open_loop.deviation_list)))))
                              
deviation_list_dms = np.concatenate((np.array(dms_open_loop.deviation_list), np.array([dms_open_loop.deviation_list[-1]]*(50 - len(dms_open_loop.deviation_list)))))
solver_time_dc = dc_open_loop.solver_time
solver_time_dms = dms_open_loop.solver_time

# %%
dms_timing["N"] = 50
dc_timing["N"] = dms_timing["N"]
dms_open_loop = solver(dms_timing, solver_bounds, nlp_opts, Q, R )  # open loop by default
dc_open_loop = solver(dc_timing, solver_bounds, nlp_opts, Q, R, cost_type = False)
dms_open_loop.set_initial_values(x_start, x_desired)
dms_open_loop.create_dms_solver()
dms_open_loop.solve()
dms_open_loop._extract_solution()
dc_open_loop.set_initial_values(x_start, x_desired)
# dc_open_loop.initial_state_guess = np.zeros((13,))
dc_open_loop.create_dc_solver()
dc_open_loop.solve()
dc_open_loop._extract_solution()
deviation_list_dc = np.vstack((deviation_list_dc, np.array(dc_open_loop.deviation_list)))
deviation_list_dms = np.vstack((deviation_list_dms, np.array(dms_open_loop.deviation_list)))
solver_time_dc = np.vstack((solver_time_dc, dc_open_loop.solver_time))
solver_time_dms = np.vstack((solver_time_dms, dms_open_loop.solver_time))
# Out:
# IPOPT status: Solve_Succeeded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:6290, in DM.<lambda>(self, name, value)
#    6289     __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 6290 __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291 __swig_getmethods__ = {}
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:74, in _swig_setattr(self, class_type, name, value)
#      73 def _swig_setattr(self, class_type, name, value):
# ---> 74     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:58, in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      57 if (name == "this"):
# ---> 58     if type(value).__name__ == 'SwigPyObject':
#      59         self.__dict__[name] = value
#
# SystemError: <class 'type'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:6290, in DM.<lambda>(self, name, value)
#    6289     __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 6290 __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291 __swig_getmethods__ = {}
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:74, in _swig_setattr(self, class_type, name, value)
#      73 def _swig_setattr(self, class_type, name, value):
# ---> 74     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:58, in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      57 if (name == "this"):
# ---> 58     if type(value).__name__ == 'SwigPyObject':
#      59         self.__dict__[name] = value
#
# SystemError: <class 'type'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:6290, in DM.<lambda>(self, name, value)
#    6289     __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 6290 __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291 __swig_getmethods__ = {}
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:74, in _swig_setattr(self, class_type, name, value)
#      73 def _swig_setattr(self, class_type, name, value):
# ---> 74     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:58, in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      57 if (name == "this"):
# ---> 58     if type(value).__name__ == 'SwigPyObject':
#      59         self.__dict__[name] = value
#
# SystemError: <class 'type'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:6290, in DM.<lambda>(self, name, value)
#    6289     __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 6290 __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291 __swig_getmethods__ = {}
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:74, in _swig_setattr(self, class_type, name, value)
#      73 def _swig_setattr(self, class_type, name, value):
# ---> 74     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:58, in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      57 if (name == "this"):
# ---> 58     if type(value).__name__ == 'SwigPyObject':
#      59         self.__dict__[name] = value
#
# SystemError: <class 'type'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:6290, in DM.<lambda>(self, name, value)
#    6289     __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 6290 __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291 __swig_getmethods__ = {}
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:74, in _swig_setattr(self, class_type, name, value)
#      73 def _swig_setattr(self, class_type, name, value):
# ---> 74     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:58, in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      57 if (name == "this"):
# ---> 58     if type(value).__name__ == 'SwigPyObject':
#      59         self.__dict__[name] = value
#
# SystemError: <class 'type'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:6290, in DM.<lambda>(self, name, value)
#    6289     __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 6290 __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291 __swig_getmethods__ = {}
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:74, in _swig_setattr(self, class_type, name, value)
#      73 def _swig_setattr(self, class_type, name, value):
# ---> 74     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:58, in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      57 if (name == "this"):
# ---> 58     if type(value).__name__ == 'SwigPyObject':
#      59         self.__dict__[name] = value
#
# SystemError: <class 'type'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[124], line 12
#      10 # dc_open_loop.initial_state_guess = np.zeros((13,))
#      11 dc_open_loop.create_dc_solver()
# ---> 12 dc_open_loop.solve()
#      13 dc_open_loop._extract_solution()
#      14 deviation_list_dc = np.vstack((deviation_list_dc, np.array(dc_open_loop.deviation_list)))
#
# File ~/flight-control-submisssion-week/formatted_code/NMPC_solver.py:489, in solver.solve(self)
#     486 def solve(self):
#     487     # solve the ocp
#     488     time_start = time.time()
# --> 489     sol = self.solver(x0=self.w0, lbx=self.lbw, ubx=self.ubw, lbg=self.lbg, ubg=self.ubg, p=vertcat(self.X_opt_current, self.initial_control_guess, self.x_desired))
#     490     time_end = time.time()
#     491     print(f"IPOPT status: %s" % self.solver.stats()["return_status"])
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:13453, in Function.__call__(self, *args, **kwargs)
#   13450       return tuple(ret)
#   13451   else:
#   13452 # Named inputs -> return dictionary
# > 13453     return self.call(kwargs)
#
# File ~/.local/lib/python3.8/site-packages/casadi/casadi.py:12324, in Function.call(self, *args)
#   12256 def call(self, *args) -> "void":
#   12257     """
#   12258       Generate a Jacobian function of output oind with respect to input iind.
#   12259
#    (...)
#   12322
#   12323     """
# > 12324     return _casadi.Function_call(self, *args)
#
# SystemError: <built-in function Function_call> returned a result with an error set

# %%
#plot each row of deviation_list_dms as a line and deviation_list_dc as a dashed line, with each row of both lists colored the same. The label for each row is the N= 5 * (i+1)
# the color for each row is the same as the color for the corresponding row in the other list
plt.figure()
for i in range(len(deviation_list_dms)):
    plt.plot(deviation_list_dms[i], label = "N = {}".format(5*(i+1)), color = "C{}".format(i))
    plt.plot(deviation_list_dc[i], linestyle = "--", color = "C{}".format(i))
plt.legend()
plt.xlabel("Time step")
plt.ylabel("Deviiation [m]")
plt.title("Deviation from desired trajectory for different Horizon lengths")
plt.savefig("N_vs_deviation.png")

# %%
# plot the graph of solver_time_dc against solver_time_dms for a range 5 t0 45 with step 5.
#solver_time_dc is a dashed line, whereas solver_time_dms is a solid line
plt.figure()
plt.plot(np.arange(5, 50, 5), solver_time_dc, linestyle = "--", label = "DC")
plt.plot(np.arange(5, 50, 5), solver_time_dms, label = "DMS")
plt.legend()
plt.xlabel("Horizon length")
plt.ylabel("Solver time [s]")
plt.title("Solver time for different Horizon lengths")
plt.savefig("N_vs_solver_time.png")

# %%
time_step_list = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5,0.75, 1]
time_step_dev_list_dc = []
time_step_dev_list_dms = []
time_step_sol_time_dms =  []
time_step_sol_time_dc = []

# %%
for time_step in time_step_list:
    dms_timing["N"] = 20
    dc_timing["N"] = dms_timing["N"]
    dms_open_loop = solver(dms_timing, solver_bounds, nlp_opts, Q, R,time_step=time_step )  # open loop by default
    dc_open_loop = solver(dc_timing, solver_bounds, nlp_opts, Q, R, cost_type = False, time_step=time_step)
    dms_open_loop.set_initial_values(x_start, x_desired)
    dms_open_loop.create_dms_solver()
    print("solver_created")
    dms_open_loop.solve()
    dms_open_loop._extract_solution()
    dc_open_loop.set_initial_values(x_start, x_desired)
    # dc_open_loop.initial_state_guess = np.zeros((13,))
    dc_open_loop.create_dc_solver()
    dc_open_loop.solve()
    print("dc solved")
    dc_open_loop._extract_solution()
    time_step_dev_list_dc.append(dc_open_loop.deviation_list[-1])
    time_step_dev_list_dms.append(dms_open_loop.deviation_list[-1])
    time_step_sol_time_dms.append(dms_open_loop.solver_time)
    time_step_sol_time_dc.append(dc_open_loop.solver_time)
# Out:
# solver_created
# IPOPT status: Solve_Succeeded
# IPOPT status: Solve_Succeeded
# dc solved
# solver_created
# IPOPT status: Solve_Succeeded
# IPOPT status: Solve_Succeeded
# dc solved
# solver_created
# IPOPT status: Solve_Succeeded
# IPOPT status: Solve_Succeeded
# dc solved
# solver_created
# IPOPT status: Solve_Succeeded
# IPOPT status: Solve_Succeeded
# dc solved
# solver_created
# IPOPT status: Solve_Succeeded
# IPOPT status: Solve_Succeeded
# dc solved
# solver_created
# IPOPT status: Solve_Succeeded
# IPOPT status: Solve_Succeeded
# dc solved
# solver_created
# IPOPT status: Solve_Succeeded
# IPOPT status: Solve_Succeeded
# dc solved
# solver_created
# IPOPT status: Solve_Succeeded
# IPOPT status: Solve_Succeeded
# dc solved

# %%
# time_step_list as the x-axis, scatterplot time_step_sol_time_dms and time_step_sol_time_dc as the y-axis, with each point colored the same as the corresponding point in time_step_sol_time_dms

time_step_sol_time_dc
# Out:
# [0.26749610900878906,
#  1.5722784996032715,
#  0.5002231597900391,
#  0.9527623653411865,
#  0.736792802810669,
#  2.102489948272705,
#  2.8508236408233643,
#  2.987398862838745]

# %%
#plot a log graph of time_stp_list as x-asis and time_step_sol_time_dms and time_step_sol_time_dc as y-axis, with time_step_sol_time_dc as a dashed line and time_step_sol_time_dms as a solid line
plt.figure()
plt.plot(time_step_list, time_step_sol_time_dc, '-o', label = "DC")
plt.plot(time_step_list, time_step_sol_time_dms,'-x', label = "DMS")
#draw the x-intercept to the x_axis to each point with the same color and show the x-coordinate of the point
for i in range(len(time_step_list)):
    plt.axvline(x=time_step_list[i], ymin=0, ymax=4.5, color = "black", linestyle = "--", linewidth = 0.75)
    plt.text(time_step_list[i], time_step_sol_time_dc[i], "{:.2f}".format(time_step_list[i]))

plt.legend()

plt.xlabel("Integration time step [s]")
plt.ylabel("Solver time [s]")
plt.title("Solution times for different time steps")
plt.savefig("time_step_vs_solver_time_n_20.png")

# %%
from NMPC_solver import *
# %load_ext autoreload
# %autoreload
x_start = [0, 0, 0]
x_desired = [-0.5,0.5, 0.5]
Q_dms =  np.diag([120,
            100,
            100,
            1e-2,
            1e-2,
            1e-2,
            1e-2,
            7e-1,
            1.0,
            4.0,
            1e-1,
            1e-1,
            1e-1])
Q_dc = np.diag([120,
            100,
            100,
            1e-2,
            1e-2,
            1e-2,
            1e-2,
            7e-1,
            1.0,
            4.0,
            1,
            1,
            1])
R = np.diag([1, 1, 1, 1])*0.06

solver_bounds = {"upper_pose_limit":[1, 1, 1.5],
                "lower_pose_limit":[-1, -1, 0],
                "upper_vel_limit":[2.5, 2.5, 2.5],
                "lower_vel_limit":[-2.5, -2.5, -2.5],
                "upper_att_limit": [inf]*4,#[1,1,1,1],
                "lower_att_limit":[-inf]*4,#[0,-1,-1,-1],
                "upper_ang_limit":[10, 10, 10],
                "lower_ang_limit":[-10, -10, -10],
                "u_min" : [ 0, 0, 0, 0],
                "u_max" : [ 22, 22, 22, 22]}

nlp_opts = {"ipopt": {"max_iter": 3000, "print_level" :0}, "jit": False, "print_time":0}
# nlp_opts = {"max_iter":1}
# nlp_opts = {"qpsol_options": {"max_iter":20}}
cost_type = "slack"      # use slack variables for the terminal cost          
# time for dms closed loop
dms_timing = { "frequency" : 50,         # sampling frequency
            # "solution_time" : 0.05,      # real world time to navigate the drone
            "N" : 20    ,   
            "DMS_RK4_step_size" : 2, # step size of RK4 method for DMS
            "degree" : 2}           # degree of the collocation polynomial  
# time for dc closed loop
dc_timing = { "frequency" : 50,         # sampling frequency
            "solution_time" : 0.1, 
            "N" : 20   , # real world time to navigate the drone
            "DMS_RK4_step_size" : 2, # step size of RK4 method for DMS
            "degree" : 2}       
time_step_dc =  0.1
time_step_dms = 0.1
min_deviation = 0.01
dms_closed_loop = solver(dms_timing, solver_bounds, nlp_opts, Q_dms, R, time_step=time_step_dms,cost_type=False, simulation_type = None) 
dc_closed_loop = solver(dc_timing, solver_bounds, nlp_opts, Q_dc, R, time_step=time_step_dc,cost_type = False, simulation_type = None,use_shift=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dms_closed_loop.set_initial_values(x_start, x_desired)
dms_closed_loop.create_dms_solver()
dms_closed_loop.run_mpc(100, min_deviation)
# print(dms_closed_loop.X_opt[:, :3])
# print(dms_closed_loop.U_opt)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
dms_closed_loop.X_opt = np.round(dms_closed_loop.X_opt, 3)
ax.plot(dms_closed_loop.X_opt[:, 0], dms_closed_loop.X_opt[:, 1], dms_closed_loop.X_opt[:, 2], 'o-', label = "Trajectory")
ax.plot(x_start[0], x_start[1], x_start[2], 'X', label = "Start Point")
ax.plot(x_desired[0], x_desired[1], x_desired[2], 'X', label = "Desired Point")
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
ax.set_zlabel('Z [m]')
plt.title("MPC trajectory with Direct Multiple Shooting")
plt.legend()
plt.savefig("dms_trajectory_n_20.pdf")
# Out:
# IPOPT status: Solve_Succeeded
# time for solver in step  2  is  0.3059992790222168
# time for step  2  is  0.30663394927978516
# IPOPT status: Solve_Succeeded
# time for solver in step  3  is  0.1376819610595703
# time for step  3  is  0.13802433013916016
# IPOPT status: Solve_Succeeded
# time for solver in step  4  is  0.1274113655090332
# time for step  4  is  0.12773633003234863
# IPOPT status: Solve_Succeeded
# time for solver in step  5  is  0.16448163986206055
# time for step  5  is  0.16482210159301758
# IPOPT status: Solve_Succeeded
# time for solver in step  6  is  0.13603901863098145
# time for step  6  is  0.13636159896850586
# IPOPT status: Solve_Succeeded
# time for solver in step  7  is  0.09702229499816895
# time for step  7  is  0.0973672866821289
# IPOPT status: Solve_Succeeded
# time for solver in step  8  is  0.09701108932495117
# time for step  8  is  0.09734106063842773
# IPOPT status: Solve_Succeeded
# time for solver in step  9  is  0.09604120254516602
# time for step  9  is  0.0963754653930664
# IPOPT status: Solve_Succeeded
# time for solver in step  10  is  0.09415674209594727
# time for step  10  is  0.0944974422454834
# IPOPT status: Solve_Succeeded
# time for solver in step  11  is  0.08351421356201172
# time for step  11  is  0.08385825157165527
# IPOPT status: Solve_Succeeded
# time for solver in step  12  is  0.08348441123962402
# time for step  12  is  0.08382534980773926
# IPOPT status: Solve_Succeeded
# time for solver in step  13  is  0.08575940132141113
# time for step  13  is  0.08608889579772949
# IPOPT status: Solve_Succeeded
# time for solver in step  14  is  0.07342195510864258
# time for step  14  is  0.07375836372375488
# IPOPT status: Solve_Succeeded
# time for solver in step  15  is  0.07342982292175293
# time for step  15  is  0.07379508018493652
# IPOPT status: Solve_Succeeded
# time for solver in step  16  is  0.0747077465057373
# time for step  16  is  0.07513642311096191
# IPOPT status: Solve_Succeeded
# time for solver in step  17  is  0.07474803924560547
# time for step  17  is  0.07513642311096191
# IPOPT status: Solve_Succeeded
# time for solver in step  18  is  0.07451033592224121
# time for step  18  is  0.07485342025756836
# IPOPT status: Solve_Succeeded
# time for solver in step  19  is  0.07309579849243164
# time for step  19  is  0.07343506813049316
# IPOPT status: Solve_Succeeded
# time for solver in step  20  is  0.0727682113647461
# time for step  20  is  0.07310843467712402
# IPOPT status: Solve_Succeeded
# time for solver in step  21  is  0.07318282127380371
# time for step  21  is  0.07350993156433105
# IPOPT status: Solve_Succeeded
# time for solver in step  22  is  0.06255221366882324
# time for step  22  is  0.06293582916259766
# IPOPT status: Solve_Succeeded
# time for solver in step  23  is  0.062406063079833984
# time for step  23  is  0.06274580955505371
# IPOPT status: Solve_Succeeded
# time for solver in step  24  is  0.0632326602935791
# time for step  24  is  0.0635993480682373
# IPOPT status: Solve_Succeeded
# time for solver in step  25  is  0.06428360939025879
# time for step  25  is  0.06470847129821777
# IPOPT status: Solve_Succeeded
# time for solver in step  26  is  0.06539630889892578
# time for step  26  is  0.06599974632263184
# IPOPT status: Solve_Succeeded
# time for solver in step  27  is  0.06401491165161133
# time for step  27  is  0.06437253952026367
# IPOPT status: Solve_Succeeded
# time for solver in step  28  is  0.0627450942993164
# time for step  28  is  0.06307196617126465
# IPOPT status: Solve_Succeeded
# time for solver in step  29  is  0.06234908103942871
# time for step  29  is  0.06267261505126953
# IPOPT status: Solve_Succeeded
# time for solver in step  30  is  0.06302785873413086
# time for step  30  is  0.06344914436340332
# IPOPT status: Solve_Succeeded
# time for solver in step  31  is  0.06520795822143555
# time for step  31  is  0.0655820369720459
# IPOPT status: Solve_Succeeded
# time for solver in step  32  is  0.06289243698120117
# time for step  32  is  0.06323623657226562
# IPOPT status: Solve_Succeeded
# time for solver in step  33  is  0.06268620491027832
# time for step  33  is  0.06302213668823242
# IPOPT status: Solve_Succeeded
# time for solver in step  34  is  0.0626974105834961
# time for step  34  is  0.06303668022155762
# IPOPT status: Solve_Succeeded
# time for solver in step  35  is  0.06443929672241211
# time for step  35  is  0.0647745132446289
# IPOPT status: Solve_Succeeded
# time for solver in step  36  is  0.06232619285583496
# time for step  36  is  0.06266331672668457
# IPOPT status: Solve_Succeeded
# time for solver in step  37  is  0.06249737739562988
# time for step  37  is  0.06282877922058105
# IPOPT status: Solve_Succeeded
# time for solver in step  38  is  0.062226057052612305
# time for step  38  is  0.06256580352783203
# IPOPT status: Solve_Succeeded
# time for solver in step  39  is  0.06703710556030273
# time for step  39  is  0.06736493110656738
# IPOPT status: Solve_Succeeded
# time for solver in step  40  is  0.06356024742126465
# time for step  40  is  0.06389617919921875
# IPOPT status: Solve_Succeeded
# time for solver in step  41  is  0.06265115737915039
# time for step  41  is  0.06297802925109863
# IPOPT status: Solve_Succeeded
# time for solver in step  42  is  0.06264925003051758
# time for step  42  is  0.06297922134399414
# IPOPT status: Solve_Succeeded
# time for solver in step  43  is  0.06423091888427734
# time for step  43  is  0.06455850601196289
# IPOPT status: Solve_Succeeded
# time for solver in step  44  is  0.0626835823059082
# time for step  44  is  0.06302428245544434
# IPOPT status: Solve_Succeeded
# time for solver in step  45  is  0.06264352798461914
# time for step  45  is  0.06296658515930176
# IPOPT status: Solve_Succeeded
# time for solver in step  46  is  0.06254315376281738
# time for step  46  is  0.06289887428283691
# IPOPT status: Solve_Succeeded
# time for solver in step  47  is  0.06371355056762695
# time for step  47  is  0.06406354904174805
# IPOPT status: Solve_Succeeded
# time for solver in step  48  is  0.06229901313781738
# time for step  48  is  0.06263399124145508
# IPOPT status: Solve_Succeeded
# time for solver in step  49  is  0.0622708797454834
# time for step  49  is  0.06260919570922852
# IPOPT status: Solve_Succeeded
# time for solver in step  50  is  0.06253862380981445
# time for step  50  is  0.06287240982055664
# IPOPT status: Solve_Succeeded
# time for solver in step  51  is  0.06316781044006348
# time for step  51  is  0.06362390518188477
# IPOPT status: Solve_Succeeded
# time for solver in step  52  is  0.06514310836791992
# time for step  52  is  0.06548738479614258
# IPOPT status: Solve_Succeeded
# time for solver in step  53  is  0.06338143348693848
# time for step  53  is  0.06371068954467773
# IPOPT status: Solve_Succeeded
# time for solver in step  54  is  0.06291985511779785
# time for step  54  is  0.06324458122253418
# IPOPT status: Solve_Succeeded
# time for solver in step  55  is  0.0620875358581543
# time for step  55  is  0.06240963935852051
# IPOPT status: Solve_Succeeded
# time for solver in step  56  is  0.06275153160095215
# time for step  56  is  0.06307554244995117
# IPOPT status: Solve_Succeeded
# time for solver in step  57  is  0.06465816497802734
# time for step  57  is  0.06515073776245117
# IPOPT status: Solve_Succeeded
# time for solver in step  58  is  0.062287330627441406
# time for step  58  is  0.06262922286987305
# IPOPT status: Solve_Succeeded
# time for solver in step  59  is  0.06269407272338867
# time for step  59  is  0.06302833557128906
# IPOPT status: Solve_Succeeded
# time for solver in step  60  is  0.06264257431030273
# time for step  60  is  0.06300091743469238
# IPOPT status: Solve_Succeeded
# time for solver in step  61  is  0.06877279281616211
# time for step  61  is  0.0691823959350586
# IPOPT status: Solve_Succeeded
# time for solver in step  62  is  0.06864428520202637
# time for step  62  is  0.06926393508911133
# IPOPT status: Solve_Succeeded
# time for solver in step  63  is  0.06434249877929688
# time for step  63  is  0.06468415260314941
# IPOPT status: Solve_Succeeded
# time for solver in step  64  is  0.06284832954406738
# time for step  64  is  0.06317639350891113
# MPC converged in  64  steps
# time taken 4.851443767547607
# average solution time 0.07580380886793137

# %%
dc_closed_loop.set_initial_values(x_start, x_desired)
dc_closed_loop.create_dc_solver()
dc_closed_loop.run_mpc(100, min_deviation)
# print(dc_closed_loop.X_opt[:, :3])
dc_closed_loop.X_opt = np.round(dc_closed_loop.X_opt, 3)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(dc_closed_loop.X_opt[:, 0], dc_closed_loop.X_opt[:, 1], dc_closed_loop.X_opt[:, 2], 'o-', label = "Trajectory")
ax.plot(x_start[0], x_start[1], x_start[2], 'X', label = "Start Point")
ax.plot(x_desired[0], x_desired[1], x_desired[2], 'X', label = "Desired Point")
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
ax.set_zlabel('Z [m]')
ax.legend()
plt.title("MPC trajectory with Direct Collocation")
plt.savefig("dc_trajectory_n_20.pdf")
# Out:
# IPOPT status: Solve_Succeeded
# time for solver in step  2  is  0.07365131378173828
# time for step  2  is  0.07409048080444336
# IPOPT status: Solve_Succeeded
# time for solver in step  3  is  0.0518796443939209
# time for step  3  is  0.0522463321685791
# IPOPT status: Solve_Succeeded
# time for solver in step  4  is  0.03455233573913574
# time for step  4  is  0.03490042686462402
# IPOPT status: Solve_Succeeded
# time for solver in step  5  is  0.02803969383239746
# time for step  5  is  0.028412580490112305
# IPOPT status: Solve_Succeeded
# time for solver in step  6  is  0.02875232696533203
# time for step  6  is  0.029149293899536133
# IPOPT status: Solve_Succeeded
# time for solver in step  7  is  0.027942180633544922
# time for step  7  is  0.02834320068359375
# IPOPT status: Solve_Succeeded
# time for solver in step  8  is  0.027614831924438477
# time for step  8  is  0.028122425079345703
# IPOPT status: Solve_Succeeded
# time for solver in step  9  is  0.031194448471069336
# time for step  9  is  0.03165912628173828
# IPOPT status: Solve_Succeeded
# time for solver in step  10  is  0.031313180923461914
# time for step  10  is  0.03176379203796387
# IPOPT status: Solve_Succeeded
# time for solver in step  11  is  0.027089595794677734
# time for step  11  is  0.02779221534729004
# IPOPT status: Solve_Succeeded
# time for solver in step  12  is  0.02738666534423828
# time for step  12  is  0.02780008316040039
# IPOPT status: Solve_Succeeded
# time for solver in step  13  is  0.027930736541748047
# time for step  13  is  0.028299331665039062
# IPOPT status: Solve_Succeeded
# time for solver in step  14  is  0.027973651885986328
# time for step  14  is  0.02838921546936035
# IPOPT status: Solve_Succeeded
# time for solver in step  15  is  0.026994943618774414
# time for step  15  is  0.027383804321289062
# IPOPT status: Solve_Succeeded
# time for solver in step  16  is  0.027890443801879883
# time for step  16  is  0.028283119201660156
# IPOPT status: Solve_Succeeded
# time for solver in step  17  is  0.031120777130126953
# time for step  17  is  0.031502485275268555
# IPOPT status: Solve_Succeeded
# time for solver in step  18  is  0.03883051872253418
# time for step  18  is  0.03923511505126953
# IPOPT status: Solve_Succeeded
# time for solver in step  19  is  0.027099132537841797
# time for step  19  is  0.027471303939819336
# IPOPT status: Solve_Succeeded
# time for solver in step  20  is  0.039928436279296875
# time for step  20  is  0.040457963943481445
# IPOPT status: Solve_Succeeded
# time for solver in step  21  is  0.025995254516601562
# time for step  21  is  0.02637028694152832
# IPOPT status: Solve_Succeeded
# time for solver in step  22  is  0.02507781982421875
# time for step  22  is  0.025446176528930664
# IPOPT status: Solve_Succeeded
# time for solver in step  23  is  0.025543689727783203
# time for step  23  is  0.025910139083862305
# IPOPT status: Solve_Succeeded
# time for solver in step  24  is  0.027692317962646484
# time for step  24  is  0.0280606746673584
# IPOPT status: Solve_Succeeded
# time for solver in step  25  is  0.03829145431518555
# time for step  25  is  0.03866124153137207
# IPOPT status: Solve_Succeeded
# time for solver in step  26  is  0.026766061782836914
# time for step  26  is  0.027132034301757812
# IPOPT status: Solve_Succeeded
# time for solver in step  27  is  0.026855945587158203
# time for step  27  is  0.027260541915893555
# IPOPT status: Solve_Succeeded
# time for solver in step  28  is  0.026705265045166016
# time for step  28  is  0.02707505226135254
# IPOPT status: Solve_Succeeded
# time for solver in step  29  is  0.027119874954223633
# time for step  29  is  0.027504920959472656
# IPOPT status: Solve_Succeeded
# time for solver in step  30  is  0.027306079864501953
# time for step  30  is  0.027755260467529297
# IPOPT status: Solve_Succeeded
# time for solver in step  31  is  0.03676152229309082
# time for step  31  is  0.0371403694152832
# IPOPT status: Solve_Succeeded
# time for solver in step  32  is  0.03074789047241211
# time for step  32  is  0.031130313873291016
# IPOPT status: Solve_Succeeded
# time for solver in step  33  is  0.028961896896362305
# time for step  33  is  0.029567241668701172
# IPOPT status: Solve_Succeeded
# time for solver in step  34  is  0.03091907501220703
# time for step  34  is  0.031286001205444336
# IPOPT status: Solve_Succeeded
# time for solver in step  35  is  0.028934001922607422
# time for step  35  is  0.0293121337890625
# IPOPT status: Solve_Succeeded
# time for solver in step  36  is  0.030895709991455078
# time for step  36  is  0.0313105583190918
# IPOPT status: Solve_Succeeded
# time for solver in step  37  is  0.034433841705322266
# time for step  37  is  0.03481912612915039
# IPOPT status: Solve_Succeeded
# time for solver in step  38  is  0.027073144912719727
# time for step  38  is  0.02747058868408203
# IPOPT status: Solve_Succeeded
# time for solver in step  39  is  0.030187606811523438
# time for step  39  is  0.030550003051757812
# IPOPT status: Solve_Succeeded
# time for solver in step  40  is  0.03303265571594238
# time for step  40  is  0.03339862823486328
# IPOPT status: Solve_Succeeded
# time for solver in step  41  is  0.026860713958740234
# time for step  41  is  0.02724146842956543
# IPOPT status: Solve_Succeeded
# time for solver in step  42  is  0.02558279037475586
# time for step  42  is  0.02596282958984375
# IPOPT status: Solve_Succeeded
# time for solver in step  43  is  0.02728581428527832
# time for step  43  is  0.02764892578125
# IPOPT status: Solve_Succeeded
# time for solver in step  44  is  0.03209090232849121
# time for step  44  is  0.0324709415435791
# IPOPT status: Solve_Succeeded
# time for solver in step  45  is  0.026497602462768555
# time for step  45  is  0.026862621307373047
# IPOPT status: Solve_Succeeded
# time for solver in step  46  is  0.030246257781982422
# time for step  46  is  0.030614376068115234
# IPOPT status: Solve_Succeeded
# time for solver in step  47  is  0.029055356979370117
# time for step  47  is  0.02943563461303711
# IPOPT status: Solve_Succeeded
# time for solver in step  48  is  0.026927471160888672
# time for step  48  is  0.027400732040405273
# IPOPT status: Solve_Succeeded
# time for solver in step  49  is  0.03128314018249512
# time for step  49  is  0.03170943260192871
# IPOPT status: Solve_Succeeded
# time for solver in step  50  is  0.03748011589050293
# time for step  50  is  0.037956953048706055
# IPOPT status: Solve_Succeeded
# time for solver in step  51  is  0.03207659721374512
# time for step  51  is  0.03273153305053711
# IPOPT status: Solve_Succeeded
# time for solver in step  52  is  0.04146575927734375
# time for step  52  is  0.041840314865112305
# IPOPT status: Solve_Succeeded
# time for solver in step  53  is  0.02740621566772461
# time for step  53  is  0.02777385711669922
# IPOPT status: Solve_Succeeded
# time for solver in step  54  is  0.028546571731567383
# time for step  54  is  0.02892470359802246
# IPOPT status: Solve_Succeeded
# time for solver in step  55  is  0.044159650802612305
# time for step  55  is  0.04461097717285156
# IPOPT status: Solve_Succeeded
# time for solver in step  56  is  0.026391029357910156
# time for step  56  is  0.026777029037475586
# IPOPT status: Solve_Succeeded
# time for solver in step  57  is  0.027426481246948242
# time for step  57  is  0.027791976928710938
# IPOPT status: Solve_Succeeded
# time for solver in step  58  is  0.028646230697631836
# time for step  58  is  0.029014110565185547
# IPOPT status: Solve_Succeeded
# time for solver in step  59  is  0.0270388126373291
# time for step  59  is  0.027410268783569336
# IPOPT status: Solve_Succeeded
# time for solver in step  60  is  0.03596830368041992
# time for step  60  is  0.036348581314086914
# IPOPT status: Solve_Succeeded
# time for solver in step  61  is  0.033919572830200195
# time for step  61  is  0.03436160087585449
# IPOPT status: Solve_Succeeded
# time for solver in step  62  is  0.03515791893005371
# time for step  62  is  0.035663604736328125
# IPOPT status: Solve_Succeeded
# time for solver in step  63  is  0.03824186325073242
# time for step  63  is  0.038602590560913086
# IPOPT status: Solve_Succeeded
# time for solver in step  64  is  0.02905726432800293
# time for step  64  is  0.02945232391357422
# IPOPT status: Solve_Succeeded
# time for solver in step  65  is  0.04020404815673828
# time for step  65  is  0.04066610336303711
# IPOPT status: Solve_Succeeded
# time for solver in step  66  is  0.029949426651000977
# time for step  66  is  0.03031301498413086
# MPC converged in  66  steps
# time taken 2.072050094604492
# average solution time 0.031394698403098366

# %%
dms_mpc_dev = np.concatenate([np.array(dms_closed_loop.deviation_list), np.array([dms_closed_loop.deviation_list[-1]]*(len(dc_closed_loop.deviation_list) - len(dms_closed_loop.deviation_list)))])
dc_mpc_dev = np.array(dc_closed_loop.deviation_list)

# %%
#plot the deviation of the drone from the desired trajectory for both methods
plt.plot(dms_mpc_dev, label = "DMS")
plt.plot(dc_mpc_dev, label = "DC", linestyle = "--")
plt.xlabel("Time step")
plt.ylabel("Deviation [m]")
plt.title("Deviation from desired reference")
plt.legend()
plt.savefig("mpc_deviation.pdf")

# %%
dc_closed_loop.U_opt.shape
# Out:
# (66, 4)

# %%
dms_closed_loop.U_opt.shape
# Out:
# (64, 4)

# %%
dms_control = np.array(dms_closed_loop.U_opt)
dc_control = np.array(dc_closed_loop.U_opt)

# %%
#plot dc_control as stairs
plt.step(np.arange(len(dc_control)), dc_control[:, 0], label = "Omega 1")
plt.step(np.arange(len(dc_control)), dc_control[:, 1], label = "Omega 2")
plt.step(np.arange(len(dc_control)), dc_control[:, 2], label = "Omega 3")
plt.step(np.arange(len(dc_control)), dc_control[:, 3], label = "Omega 4")
plt.xlabel("Time step")
plt.ylabel("Control input in RPM")
plt.title("Control input for DC")
plt.legend()
plt.savefig("dc_control.pdf")

# %%
#plot dms_control as stairs
plt.step(np.arange(len(dms_control)), dms_control[:, 0], label = "Omega 1")
plt.step(np.arange(len(dms_control)), dms_control[:, 1], label = "Omega 2")
plt.step(np.arange(len(dms_control)), dms_control[:, 2], label = "Omega 3")
plt.step(np.arange(len(dms_control)), dms_control[:, 3], label = "Omega 4")
plt.xlabel("Time step")
plt.ylabel("Control input in RPM")
plt.title("Control input for DMS")
plt.legend()
plt.savefig("dms_control.pdf")

# %%
dms_control_list = np.array(dms_closed_loop.control_list)
dms_roll = dms_control_list[:, 0]
dms_pitch = dms_control_list[:, 1]
dms_yaw_rate = dms_control_list[:, 2]
dms_thrust = dms_control_list[:, 3]

dc_control_list = np.array(dc_closed_loop.control_list)
dc_roll = dc_control_list[:, 0]
dc_pitch = dc_control_list[:, 1]
dc_yaw_rate = dc_control_list[:, 2]
dc_thrust = dc_control_list[:, 3]
# plot dc_roll and dc_pitch as dashed stairs, dms_roll and dms_pitch as stairs
plt.step(np.arange(len(dc_roll)), dc_roll, label = "DC Roll", linestyle = "--")
plt.step(np.arange(len(dc_pitch)), dc_pitch, label = "DC Pitch", linestyle = "--")
plt.step(np.arange(len(dms_roll)), dms_roll, label = "DMS Roll")
plt.step(np.arange(len(dms_pitch)), dms_pitch, label = "DMS Pitch")
plt.xlabel("Time step")
plt.ylabel("Setpoint( deg)")
plt.title("Roll and Pitch setpoint")
plt.legend()
plt.savefig("roll_pitch_setpoint.pdf")

# %%
#plot thrust as stairs
plt.step(np.arange(len(dc_thrust)), dc_thrust, label = "DC Thrust", linestyle = "--")
plt.step(np.arange(len(dms_thrust)), dms_thrust, label = "DMS Thrust")
plt.xlabel("Time step")
plt.ylabel("Setpoint as an integer")
plt.title("Thrust setpoint")
plt.legend()
plt.savefig("thrust_setpoint.pdf")

# %%
#plot yaw_rate as stairs
plt.step(np.arange(len(dc_yaw_rate)), dc_yaw_rate, label = "DC Yaw Rate", linestyle = "--")
plt.step(np.arange(len(dms_yaw_rate)), dms_yaw_rate, label = "DMS Yaw Rate")
plt.xlabel("Time step")
plt.ylabel("Setpoint( deg/s)")
plt.title("Yaw Rate setpoint")
plt.legend()
plt.savefig("yaw_rate_setpoint.pdf")
